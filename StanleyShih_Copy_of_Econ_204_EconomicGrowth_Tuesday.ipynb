# %% [markdown]
# <a href="https://colab.research.google.com/github/Stanleyshih722/DKU_Econ204/blob/main/StanleyShih_Copy_of_Econ_204_EconomicGrowth_Tuesday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Step 1: Define the Exognous Variables**
#
# The saving rate: $s$
#
# The depreciation rate: $\delta$
#
# The popoulation growth rate: $n$
#
# The Technology level: $A$
#
# The Initial labor level: $L(0)$
#
# The Initial capital level: $K(0)$
#
# ## You can change the exogenous variable in the next box and go to Runtime-choose run all. Then you will see how the steady state will change Please make sure you change only one variable each time to see the comparative statics of that variable change.

# %%
s = 0.5
delta = 0.1
n=2
A=10
L0=100
K0=100

# %%
k0=K0/L0

# %% [markdown]
# Simulate $L =L(0)*e^{nt}$

# %%
### import the package
import numpy as np

# %%
### define the function
def L(t):
  L=L0*np.exp(n*t)
  return L

# %%
### check the initial value
L(0)
# Out:
# 100.0

# %%
t = np.linspace(0, 10)
L=L(t)

# %%
### plot the function
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(20,10))

plt.plot(t, L)
plt.show()

# %%
### plot the function with yscale in "log"
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(20,10))

plt.plot(t, L)
plt.yscale("log")
plt.show()

# %% [markdown]
# #**Step 2: Plot the Production Function**
#
# $y=A*k^{\beta}$

# %%
beta = 0.5

# %%
### define the function
def y(k):
  y=A*np.power(k,beta)
  return y

# %%
## check the initial condition
y(k0)
# Out:
# 10.0

# %%
k = np.linspace(k0, 100)
y=y(k)

# %%
### plot the function
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(20,10))

plt.plot(k, y)
plt.show()

# %% [markdown]
# #**Step 3: Solve for the steady State**
#
# Refers to Latex Symbol here: https://artofproblemsolving.com/wiki/index.php/LaTeX:Symbols
#
# $0=\bigtriangleup k/k=s*y(k)-s*\delta-n $

# %% [markdown]
# Plot $g(k)=s*A*k^{\beta-1}$

# %%
def G(k):
  g=s*A*np.power(k,beta-1)
  return g

# %%
G(k0)
# Out:
# 5.0

# %%
k = np.linspace(k0, 100)
g1=G(k)

# %%
### plot the function
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(20,10))

plt.plot(k, g1)
plt.show()

# %%
s*delta+n
# Out:
# 2.05

# %%
### plot the function
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(20,10))

plt.plot(k, g1)
plt.axhline(y=s*delta+n)
plt.xlabel('$k$',fontsize=20)
plt.show()

# %% [markdown]
# ### Solve for the steady state $k^{*}$

# %%
from sympy.solvers import solve
from sympy import Symbol
k=Symbol('k')

# %%
k_steady=solve(s*A*np.power(k,beta)/k-s*delta-n,k)
k_steady
# Out:
# [5.94883997620464]

# %% [markdown]
# **Step 4: Plot the Steady State Economy**

# %%
y_steady = A*np.power(k_steady,beta)
y_steady
# Out:
# array([24.3902439024390], dtype=object)

# %%
def Y(t):
  Y = y_steady*L0*np.exp(n*t)
  return Y

# %%
t = np.linspace(0, 10)
Y=Y(t)

# %%
### plot the function
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(20,10))

plt.plot(t, Y)
plt.show()

# %% [markdown]
# #**Technology Growth**
#
# #$y=y(0)*e^{at}$

# %%
### define the function
def y(t):
  y = y0*np.exp(a*t)
  return y

# %% [markdown]
# **When technology level a=0**

# %%
y0=y_steady
a=5

# %%
t = np.linspace(0, 10)
y1 =y(t)
y(8)
# Out:
# array([5.74110406919561e+18], dtype=object)

# %%
### plot the function
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(20,10))

plt.plot(t, y1)
plt.show()

# %% [markdown]
# ## when technology level a=1
#
# ## Note: We can change the value of a in the next box and go to Runtime and choose run all. Then you will see the new figure for the comparative statics of a.

# %%
y0=y_steady
a=8

# %%
t = np.linspace(0, 10)
y2 =y(t)
y(8)
# Out:
# array([1.52076806849064e+29], dtype=object)

# %%
### plot the function
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(20,10))
plt.plot(t,y1,label='a=5')
plt.plot(t,y2,label="a=8")
plt.legend (fontsize=14)
plt.yscale("log")
plt.title("Steady State GDP per capita $y$ with different technology level growth rate $a$",fontsize=16)
plt.show()
